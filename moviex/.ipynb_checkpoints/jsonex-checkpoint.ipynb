# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
from scipy.interpolate import lagrange

# %%
movies_data = pd.read_csv('tmdb_5000_movies.csv')

# %%
movies_credits = pd.read_csv('tmdb_5000_credits.csv')

# %%
movies_credits.rename(columns={"movie_id" : "id"}, inplace=True)

# %%
movies = pd.merge(movies_data, movies_credits, on=["title", "id"])

# %%
#jdata = json.loads(movies.genres[0])
#json.dumps(jdata) 
#tempdata = pd.DataFrame(jdata)
#tempdata

# %%
genres_data = pd.DataFrame()

# %%
#genres_data = pd.DataFrame()
for j in movies.genres:
    jda = json.loads(j)
    r_data = pd.DataFrame(jda)
    genres_data = pd.concat([genres_data, r_data], axis="index")
genres_data = genres_data.drop_duplicates(subset = "name")

# %%
genres_data.index = range(0,genres_data.index.size)

# %%
movies['genres'] = movies.genres.transform(json.loads)

# %%
def get_movie_type(element):      #定義一個取名字的函數，作用到每一行中去
    type_list = []
    for value in element:
        name = value['name']
        type_list.append(name)
    return ' '.join(type_list)

# %%
type_relation = pd.DataFrame()

# %%
type_relation['genres'] = movies.genres.transform(get_movie_type)

# %%
type_relation['title'] = movies.title

# %%
for i in genres_data.name:
    type_relation[i] = type_relation.genres.str.contains(i).astype('int') #將bool變成int

# %%
type_relation['release_year'] = pd.to_datetime(movies.release_date).dt.year

# %%
groupby_year = type_relation.groupby(type_relation.release_year).sum() #根據年份統計每種類型的合計

# %%
plt.figure(figsize= (16,8))
x = groupby_year.index
for genre in genres_data.name:
    y = groupby_year[genre]
    plt.plot(x, y)
plt.legend(genres_data.name)
plt.show()

# %%
data  = pd.DataFrame({'state':['Florida','Florida','Texas','Texas'],
                      'a':[4,5,1,3],
                      'b':[6,10,3,11]
                      })

# %%
data
# Out:
#      state  a   b
# 0  Florida  4   6
# 1  Florida  5  10
# 2    Texas  1   3
# 3    Texas  3  11

# %%
testlist = movies.genres[0]

# %%
def trans_name(self):
    testname = ''
    for i in self:
        testname += i['name'][0].lower()
    return testname

# %%
movies.genres.transform(trans_name)[0]
# Out:
# 'aafs'

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4803 entries, 0 to 4802
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
#  15  status                4803 non-null   object
#  16  tagline               3959 non-null   object
#  17  title                 4803 non-null   object
#  18  vote_average          4803 non-null   float64
#  19  vote_count            4803 non-null   int64
#  20  cast                  4803 non-null   object
#  21  crew                  4803 non-null   object
# dtypes: float64(3), int64(4), object(15)
# memory usage: 1023.0+ KB

# %%
budgets = movies.loc[:,['title','budget','vote_count','popularity','revenue']]
budgets.popularity = budgets.popularity * 1000000
budgets['fit'] = budgets.revenue - budgets.budget

# %%
mask = budgets.budget == 0
budgets = budgets.drop(labels=budgets[mask].index)
fit_bar = budgets.sort_values(by = "fit", ascending = False).head(10)
fit_bar
# Out:
#                                              title     budget  vote_count  \
# 0                                           Avatar  237000000       11800
# 25                                         Titanic  200000000        7562
# 28                                  Jurassic World  150000000        8662
# 44                                       Furious 7  190000000        4176
# 16                                    The Avengers  220000000       11776
# 7                          Avengers: Age of Ultron  280000000        6767
# 124                                         Frozen  150000000        5295
# 546                                        Minions   74000000        4571
# 329  The Lord of the Rings: The Return of the King   94000000        8064
# 31                                      Iron Man 3  200000000        8806
#
#       popularity     revenue         fit
# 0    150437577.0  2787965087  2550965087
# 25   100025899.0  1845034188  1645034188
# 28   418708552.0  1513528810  1363528810
# 44   102322217.0  1506249360  1316249360
# 16   144448633.0  1519557910  1299557910
# 7    134279229.0  1405403694  1125403694
# 124  165125366.0  1274219009  1124219009
# 546  875581305.0  1156730962  1082730962
# 329  123630332.0  1118888979  1024888979
# 31    77682080.0  1215439994  1015439994

# %%
plt.figure(figsize = (12,8))
x_labels = []
for i in fit_bar.title:
    x_labels.append(i[0:9])
plt.bar(x_labels, fit_bar.revenue, color = "hotpink", label = "fit")
plt.bar(x_labels, fit_bar.budget, color = "skyblue", label = "popularity")
plt.legend() 
plt.show()

# %%
genres_count = type_relation[genres_data.name].sum()
plt.figure(figsize = (16,12))
plt.pie(genres_count, labels = genres_count.index, autopct = '%1.1f%%')
plt.show()

# %%
plt.figure(figsize = (10,8))
plt.barh(genres_count.index, genres_count)
plt.show()

# %%
genre_profit = pd.DataFrame()
for movie_type in genres_data.name:
    genre_profit[movie_type] = type_relation[movie_type]
genre_profit['profit'] = budgets.fit

# %%
profit_mean_by_genres = []
for t in genres_data.name:
    profit_mean_by_genres.append(genre_profit.loc[genre_profit[t] == 1, 'profit'].mean())

# %%
value = {'genres_mean':genres_data.name, 'profit_mean':profit_mean_by_genres}
profit_mean = pd.DataFrame(value).sort_values(by = "profit_mean")

# %%
plt.figure(figsize = (6,4))
plt.barh(profit_mean.genres_mean, profit_mean.profit_mean)
plt.show()
