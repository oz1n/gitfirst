# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load('国民经济核算季度数据.npz', allow_pickle = True) #导入数据文件, 后者选项解决不能导入问题

# %%
data.files
# Out:
# ['columns', 'values']

# %%
columns = data['columns']

# %%
values = data['values']

# %%
#value_label = values[:,:2]

# %%
#value_data = values[:,2:]

# %%
data2017 = values[-1,3:6]
explode = [0.1, 0.01, 0.01]
labels = columns[3:6]

# %%
plt.figure(figsize = (6, 6))
plt.pie(data2017, explode = explode, labels =labels, 
        colors = ["hotpink", "skyblue", "palegreen"],
       autopct = "%.1f%%", labeldistance = 1.2, pctdistance = 0.5)
plt.show()
